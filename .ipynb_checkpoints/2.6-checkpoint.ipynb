# %%
# %matplotlib inline
import torch
from torch.distributions import multinomial
from d2l import torch as d2l

# %%
fair_probs = torch.ones([6]) / 6#实际概率
multinomial.Multinomial(1, fair_probs).sample()#置一次筛子并取样
# Out:
# tensor([0., 0., 1., 0., 0., 0.])

# %%
multinomial.Multinomial(1000, fair_probs).sample()
# Out:
# tensor([156., 156., 164., 175., 172., 177.])

# %%
counts = multinomial.Multinomial(10, fair_probs).sample((500,))#500组实验，每次取样十次

# %%
counts
# Out:
# tensor([[3., 2., 3., 1., 0., 1.],
#         [3., 2., 0., 3., 1., 1.],
#         [1., 4., 1., 1., 1., 2.],
#         ...,
#         [2., 6., 0., 0., 2., 0.],
#         [0., 2., 2., 4., 2., 0.],
#         [4., 1., 0., 2., 2., 1.]])

# %%
cum_counts = counts.cumsum(dim=0)

# %%
cum_counts
# Out:
# tensor([[  3.,   2.,   3.,   1.,   0.,   1.],
#         [  6.,   4.,   3.,   4.,   1.,   2.],
#         [  7.,   8.,   4.,   5.,   2.,   4.],
#         ...,
#         [817., 836., 837., 841., 812., 837.],
#         [817., 838., 839., 845., 814., 837.],
#         [821., 839., 839., 847., 816., 838.]])

# %%
estimates = cum_counts / cum_counts.sum(dim=1, keepdims=True)
estimates
# Out:
# tensor([[0.3000, 0.2000, 0.3000, 0.1000, 0.0000, 0.1000],
#         [0.3000, 0.2000, 0.1500, 0.2000, 0.0500, 0.1000],
#         [0.2333, 0.2667, 0.1333, 0.1667, 0.0667, 0.1333],
#         ...,
#         [0.1641, 0.1679, 0.1681, 0.1689, 0.1631, 0.1681],
#         [0.1637, 0.1679, 0.1681, 0.1693, 0.1631, 0.1677],
#         [0.1642, 0.1678, 0.1678, 0.1694, 0.1632, 0.1676]])

# %%
d2l.set_figsize((6, 4.5))
for i in range(6):
    d2l.plt.plot(estimates[:, i].numpy(),
                 label=("P(die=" + str(i + 1) + ")"))
d2l.plt.axhline(y=0.167, color='black', linestyle='dashed')
d2l.plt.gca().set_xlabel('Groups of experiments')
d2l.plt.gca().set_ylabel('Estimated probability')
d2l.plt.legend();

# %%
multinomial.Multinomial(10,fair_probs).sample((500,))
# Out:
# tensor([[3., 3., 0., 1., 1., 2.],
#         [0., 0., 4., 3., 1., 2.],
#         [0., 2., 1., 1., 5., 1.],
#         ...,
#         [3., 1., 1., 1., 1., 3.],
#         [3., 1., 1., 1., 2., 2.],
#         [1., 1., 1., 3., 3., 1.]])
